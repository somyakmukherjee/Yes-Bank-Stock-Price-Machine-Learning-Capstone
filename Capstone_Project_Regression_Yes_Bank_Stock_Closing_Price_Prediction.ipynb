# %% [markdown]
# <a href="https://colab.research.google.com/github/somyakmukherjee/Yes-Bank-Stock-Price-Machine-Learning-Capstone/blob/main/Capstone_Project_Regression_Yes_Bank_Stock_Closing_Price_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name** - **Regression - Yes Bank Stock Closing Price Prediction**
#
# The history of Yes Bank can be traced back to 1999, when three Indian bankers Ashok Kapur, Harkirat Singh, Rana Kapoor decided to launch a non-banking financial enterprise together. The three Indian promoters each owned 25% of the company. In 2003, it was rebranded as the Yes Bank.
#
# The bank's management, under the leadership of Kumar, immediately repositioned itself and dealt with all internal and market related challenges to restore customer and depositor confidence. Under the coordinated efforts of the new board and management, Mehta assured shareholders of a speedy recovery, even as the Reserve Bank of India (RBI), State Bank of India (SBI), HDFC Bank, ICICI Bank, Axis Bank and other banks lent it support through the historic Yes Bank Reconstruction Scheme 2020.
#
# Since 2018, it has been in the news because of the fraud case involving Rana Kapoor. Owing to this fact, it was interesting to see how that impacted the stock prices of the company and whether Time series models or any other predictive models can do justice to such situations. This dataset has monthly stock prices of the bank since its inception and includes closing, starting, highest, and lowest stock prices of every month.

# %% [markdown]
# ##### **Project Type**    - Regression
# ##### **Contribution**    - Individual
# Prepared & presented by **Somyak Mukherjee**

# %% [markdown]
# ![gettyimages-1165887279-2048x2048.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The main objective is to predict the stock's closing price of the month.To determine the YES bank's stock's future value on the national stock exchange. The advantage of a successful prediction of a stock's future price could results insignificant profit. The efficient-market hypothesis recommends that stock costs mirror all right now accessible data and any value changes that are not founded on recently uncovered data subsequently are an unpredictable.We have to build model which help us to predict the future stock prices.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/somyakmukherjee/Yes-Bank-Stock-Price-Machine-Learning-Capstone

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In finance, the term "stock" refers to a share in the ownership of a company. When a company decides to raise funds, it can do so by issuing stocks, which are also known as "shares" or "equity." Each share represents a small piece of ownership in the company.
#
# Investing in stocks can be a way to potentially earn a return on your investment, but it also comes with risks. The value of a stock can go up or down, and there is no guarantee that you will make a profit. It's important to do your research and understand the risks before investing in any stock
#
# Yes Bank is a well-known bank in the Indian financial domain. Since 2018, it has been in the news because of the fraud case involving Rana Kapoor. Owing to this fact, it was interesting to see how that impacted the stock prices of the company and whether Time series models or any other predictive models can do justice to such situations. This dataset has monthly stock prices of the bank since its inception and includes closing, starting, highest, and lowest stock prices of every month. The main objective is to predict the stock’s closing price of the month.
#
# A Stock or share (also known as a company’s 'equity') is a financial instrument that represents ownership in a company. Units of stock are called "shares." Stocks are bought and sold predominantly on stock exchanges, though there can be private sales as well, and are the foundation of many individual investors' portfolios.
#
# Our main objective is to predict the stock’s closing price of the month.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import necessary libraries
import numpy as np              # Import NumPy for numerical operations
import pandas as pd             # Import Pandas for data manipulation
import matplotlib.pyplot as plt # Import Matplotlib for data visualization
# %matplotlib inline
from datetime import datetime
import seaborn as sns           # Import Seaborn for enhanced data visualization
import plotly.graph_objects as go  # Import Plotly for interactive plots
from sklearn.model_selection import train_test_split,TimeSeriesSplit# Import train_test_split for data splitting
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import ElasticNetCV    # Import LinearRegression model
from sklearn.model_selection import GridSearchCV      # Import GridSearchCV for hyperparameter tuning
from xgboost import XGBRegressor         # Import XGBoost library for boosting-based models
from sklearn.ensemble import RandomForestRegressor    # Import RandomForestRegressor for ensemble-based models

from sklearn.metrics import mean_absolute_error, r2_score  # Import metrics for model evaluation

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Loading

# %%
# Mounting drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Accessing the dataset.
path = '/content/drive/MyDrive/MLcapstone/data_YesBank_StockPrices.csv'
df = pd.read_csv(path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head() # fetching first five rows from dataset using head() function
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30
# 3  Oct-05  13.20  14.47  12.40  12.99
# 4  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (185, 5)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# Length: 185, dtype: bool

# %%
# Checking the presence of duplicate data.
len(df[df.duplicated()])
# Dataset has no duplicate data.
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Dataset has no missing values.
# Out:
# Date     0
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %%
# Visualizing the missing values
missingvalues_percentage = df.isna().sum().sort_values(ascending= False)/len(df)
missingvalues_percentage_disp = round((df.isna().sum().sort_values(ascending= False)/len(df))*100,2)
missingvalues_percentage_disp
# Out:
# Date     0.0
# Open     0.0
# High     0.0
# Low      0.0
# Close    0.0
# dtype: float64

# %%
# Visualizing the missing values
sns.heatmap(df.isna(),annot=True,cmap='BuPu')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This data contains stock prices of Yes Bank, which is a well-known bank in the Indian financial domain. The dataset has monthly stock prices of the bank since its inception and includes closing, starting, highest, and lowest stock prices of every month.
#
# The main objective is to predict the stock's closing price of the month.
#
# The dataset has 185 rows and 5 columns, with a size of 925. And also the dataset has no duplicate and no null values.This dataset contains 5 columns: Date, Open, High, Low & Close. Dataset has no duplicate data & missing/null value.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#              Open        High         Low       Close
# count  185.000000  185.000000  185.000000  185.000000
# mean   105.541405  116.104324   94.947838  105.204703
# std     98.879850  106.333497   91.219415   98.583153
# min     10.000000   11.240000    5.550000    9.980000
# 25%     33.800000   36.140000   28.510000   33.450000
# 50%     62.980000   72.550000   58.000000   62.540000
# 75%    153.000000  169.190000  138.350000  153.300000
# max    369.950000  404.000000  345.500000  367.900000

# %% [markdown]
# ### Variables Description

# %% [markdown]
# We have a dataset of YES BANK which contain monthly stock prices of bank since its opening.It contain multiple features like:-
#
# **Date**: It denotes the month & year with respect to the price of the stock.
#
# **Open**: The price at which a stock started trading that month.
#
# **High**: Refers to the maximum price of the stock.
#
# **Low**: Refers to the minimum price of the stock.
#
# **Close**: Refers to the final trading price for that month.
#
# "Close" is the dependent variable or the target variable in this case & rest all are independent variables or input variables. The closing price refers to a stock's trading price closed at the end of a trading day (Numerical).It's a depenedent variable which we need to predict from our respetive ML models.The closing price is calculated as the weighted average price of the last 30 minutes, i.e. from 3:00 PM to 3:30 PM in case of equity.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in df.columns.tolist():
  print('Unique values in ',i, 'are', df[i].nunique())
# Out:
# Unique values in  Date are 185
# Unique values in  Open are 183
# Unique values in  High are 184
# Unique values in  Low are 183
# Unique values in  Close are 185

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Checking the format of "Date" column
df['Date']
# Out:
# 0      Jul-05
# 1      Aug-05
# 2      Sep-05
# 3      Oct-05
# 4      Nov-05
#         ...
# 180    Jul-20
# 181    Aug-20
# 182    Sep-20
# 183    Oct-20
# 184    Nov-20
# Name: Date, Length: 185, dtype: object

# %%
# Converting 'Date' into datetime - 'YYYY-MM-DD' format
# Using Pandas to_datetime() method helps to convert string Date time into Python Date time object
# Apply lambda function to convert  all values of date column to proper format

df['Date'] = pd.to_datetime(df['Date'].apply(lambda x: datetime.strptime(x, '%b-%y')))
df['Date']
# Out:
# 0     2005-07-01
# 1     2005-08-01
# 2     2005-09-01
# 3     2005-10-01
# 4     2005-11-01
#          ...
# 180   2020-07-01
# 181   2020-08-01
# 182   2020-09-01
# 183   2020-10-01
# 184   2020-11-01
# Name: Date, Length: 185, dtype: datetime64[ns]

# %%
# check the changes
df.tail()
# Out:
#           Date   Open   High    Low  Close
# 180 2020-07-01  25.60  28.30  11.10  11.95
# 181 2020-08-01  12.00  17.16  11.85  14.37
# 182 2020-09-01  14.30  15.34  12.75  13.15
# 183 2020-10-01  13.30  14.01  12.11  12.42
# 184 2020-11-01  12.41  14.90  12.21  14.67

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# From the above output, we can seen that the format of Date is "MMMM-YY". So I need to convert in proper date format "YYYY-MM-DD".
#
# But the problem is that the ML model like Linear Regression doesn't work on "Date" data. So I have converted it into numerical column.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Visualisation of closing price with respect to dates

# %%
# Dividing the dataset into dependent & independent variable.
X = df.drop(['Close','Date'],axis=1)         # Independent variables.
Y = df['Close']                             # Dependent variable.

# %%
# Chart - 1 visualization code
# Visualisation of closing price with respect to dates.
plt.figure(figsize=(15,6))
plt.xlabel('Year', fontsize=10)
plt.ylabel('Close Prices', fontsize=10)
plt.plot(df['Date'], df['Close'],linewidth=5,color='Orange')
plt.title('Closing Prices along different time period', fontsize=15)
plt.grid()
plt.show()

# %%
# Plot the Line for each numerical column(Open, Close, High) and see how stock price is affected after fraud case 2018
plt.figure(figsize=(15,6))
plt.plot(df['Close'])
plt.plot(df['Open'])
plt.plot(df['High'])
plt.legend(['Close','Open','High'])
plt.title("Stock price affected after fraud case 2018", fontsize=15)
plt.xlabel("Year", fontsize=10)
plt.grid()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Timeseries analysis was needed to be carried out to understand the nature of stock price chronologically over time, A **Bi-Variate** plot was chosen to visualise the data.
#
# The above plot indicates a more detailed approach with the progression of time along the 'X' axis and signifies the stock price[open, close, high] along the 'Y' axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. From the above line plot ,we can conclude that the stock price is keep on increasing till 2018.
#
# 2. But after 2018 , the stock price is keep on decreasing due the fraud case involving Rana Kapoor.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The line plot provides a detailed timeseries analysis of the chronological progression of time vs the stock price of Yes Bank.
#
# The plot clearly depicts that the stock price is keep on increasing till 2018 but after 2018 there has been a significant drop in stock price value.

# %% [markdown]
# #### Chart - 2 Stock Prices highs after 2018 using Barchart

# %%
# Creating new dataframe
new_df = df[['Date','High']].tail(36)
new_df
# Out:
#           Date    High
# 149 2017-12-01  319.00
# 150 2018-01-01  366.00
# 151 2018-02-01  366.50
# 152 2018-03-01  325.80
# 153 2018-04-01  368.75
# 154 2018-05-01  364.40
# 155 2018-06-01  350.10
# 156 2018-07-01  393.35
# 157 2018-08-01  404.00
# 158 2018-09-01  350.00
# 159 2018-10-01  268.45
# 160 2018-11-01  231.40
# 161 2018-12-01  194.30
# 162 2019-01-01  236.30
# 163 2019-02-01  236.90
# 164 2019-03-01  281.30
# 165 2019-04-01  285.90
# 166 2019-05-01  178.05
# 167 2019-06-01  153.80
# 168 2019-07-01  110.60
# 169 2019-08-01   92.40
# 170 2019-09-01   72.55
# 171 2019-10-01   76.65
# 172 2019-11-01   75.35
# 173 2019-12-01   70.50
# 174 2020-01-01   48.50
# 175 2020-02-01   40.70
# 176 2020-03-01   87.95
# 177 2020-04-01   30.45
# 178 2020-05-01   31.60
# 179 2020-06-01   31.95
# 180 2020-07-01   28.30
# 181 2020-08-01   17.16
# 182 2020-09-01   15.34
# 183 2020-10-01   14.01
# 184 2020-11-01   14.90

# %%
# Chart - 2 visualization code
# Plot stock price Highs using bar graph

#set seaborn plotting aesthetics
sns.set(style='white')

#create stacked bar chart
sns.barplot(x=new_df['High'], y=new_df['Date'],  palette='flare',edgecolor=sns.color_palette('dark',10),orient='h')

#rotate x-axis labels
plt.xticks(rotation=90)

#add axis titles
plt.ylabel('Date',fontsize= 10)
plt.xlabel("Stock Price",fontsize= 10)

#add overall title
plt.title("Stock Prices highs after 2018",fontsize= 18)

# Set plot size
plt.gcf().set_size_inches(15,10)

#Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This study aims at providing stock price highs after the 2018 crash. A **Uni-Variate** analysis was chosen for this and a **Bar plot** was visualised.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Here we can see that the stock prices are skyrocketing just before the collapse after 2018. A certain govt. measures were taken to boost the stock price in 2019 but it gradually decreased at its lowest in 2020.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# In conclusion, we can say that the stock prices are skyrocketing just before the collapse after 2018. A certain govt. measures were taken to boost the stock price in 2019 but it gradually decreased at its lowest in 2020.

# %% [markdown]
# #### Chart - 3 Visualisation of skewness of the independent variable dataset(Stock Price: Open, Close, High)

# %%
# Chart - 3 visualization code
# Visualisation of skewness of the independent variable dataset(Stock Price: Open, Close, High).
for labels in X:
    plt.figure(figsize=(18,5))
    plt.subplot(1,2,2)
    fig = sns.histplot(df[labels],color='red', kde=True)
    fig.set_ylabel('Density',fontsize=15)
    fig.set_xlabel(labels,fontsize=15)
    plt.grid()
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is a way to visualize data distribution with the help of one or more variables. Here we are using histplot() function to visualize different data distributions in stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can see that the above distibution is not a Normal Distribution. It's a Positively Skewed Distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The positively skewed distribution is a distribution where the mean, median, and mode of the distribution are positive rather than negative or zero, i.e., data distribution occurs more on the one side of the scale with a long tail on the right side. It is also known as the **right-skewed distribution**, where the mean is generally to the right side of the data median.
#
# In a positively skewed distribution, the mean is greater than the median. This occurs because the data is skewed towards lower values, pulling the mean towards that side, while the median remains closer to the middle of the data.

# %% [markdown]
# #### Chart - 4 Log Transformation

# %%
# Chart - 4 visualization code
# Applying log tranformation on independent variable dataset.
for labels in X:
    plt.figure(figsize=(18,5))
    plt.subplot(1,2,2)
    vis = sns.histplot(np.log10(df[labels]),color='rebeccapurple', kde=True)
    vis.set_ylabel('Density',fontsize=15)
    vis.set_xlabel(labels,fontsize=15)
    plt.grid()
    plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is a way to visualize data distribution with the help of one or more variables. Here we are using histplot() function to visualize different data distributions in stock prices.
#
# In Chart 3, we have seen that the plot is not a Normal Distribution.It's a Positively Skewed Distribution.That's why I need to convert it into Normal Distribution using Log Tranformation.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Independent variable dataset i.e stock price(High, Open, Close) now seems to be normally dirtributed a bit after log transformation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Normal distribution is a probability and statistical concept widely used in scientific studies for its many benefits. Just to name a few of these benefits— normal distribution is simple. Its mean, median and mode have the same value and it can be defined with just two parameters: mean and variance.
#
# Logarithms are essential tools in statistical modeling and statistical analysis. A logarithm can be defined with respect to a base (b) where the base b-logarithm of X is equal to y because X equals to the b to the power of y (log(X) =y because X = b ʸ).
#
# Log transformation is a data transformation method in which it replaces each variable x with a log(x). The choice of the logarithm base is usually left up to the analyst and it would depend on the purposes of statistical modeling.
#
# Independent variable dataset i.e stock price(High, Open, Close) now seems to be normally dirtributed a bit after log transformation.

# %% [markdown]
# #### Chart - 5 Distribution of all the numerical features present

# %%
# Check the numerical columns in dataset
numerical_columns = df.describe().columns
numerical_columns
# Out:
# Index(['Open', 'High', 'Low', 'Close'], dtype='object')

# %%
# Chart - 5 visualization code
# plot a bar plot for each numerical feature and see the distribution is normal or not

for col in numerical_columns:
    plt.figure(figsize=(20, 6))
    plt.subplot(1, 2, 1)
    sns.histplot(df[col], color="red", kde = True)

# The Axes. axvline() function in axes module of matplotlib library is used to add a vertical line across the axis.
# It will show where the "mean" and "median" lie for each plot

    plt.ylabel("Count", size=14)
    plt.axvline(df[col].mean(),color='magenta',linewidth=1.5)
    plt.axvline(df[col].median(),color='red',linestyle="dashed",linewidth=1.5)

# create boxplot to see if there is any outliers in any column or not
# subplot() function is used to create boxplot in this figure itself
# boxplot() is used to check outliers are present in respective features or not

    plt.subplot(1, 2, 2)
    sns.boxplot(y=df[col], color="blue")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is a way to visualize data distribution with the help of one or more variables. Here we are using histplot() function to visualize different data distributions in stock prices.
#
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The above graph shows that they are not a normal distribution curve.
# 2. The mean and median should be equal for perfect normal distribution
#  curve but here the mean is not equal to median.
# 3. We need to convert all the features to normal distribution using log transformation.
# 4. By using the boxplot we can also see that the **Outliers** are also present in each column. We can try to convert our features to normal distribution using log transform. By this way, we can also remove outliers from the dataset.

# %% [markdown]
# #### Chart - 6 Log Transformation

# %%
# Chart - 6 visualization code
# Log tranformation to convert the data distribution to normal distribution

for col in numerical_columns:
    plt.figure(figsize=(20, 6))
    plt.subplot(1, 2, 1)
    plt.title("Distribution Curve")

# np.log() is a method in numpy library to convert our dataset values into log transformation to get a normal distribution curve

    feature_to_log = np.log(df[col])  # assign log tranformation value into a variable
    sns.histplot(feature_to_log, color="red", kde=True)

# The Axes. axvline() function in axes module of matplotlib library is used to add a vertical line across the axis.
# It will show where the "mean" and "median" lie for each plot

    plt.ylabel("Count", size=14)
    plt.axvline(feature_to_log.mean(),color='magenta',linewidth=1.5)
    plt.axvline(feature_to_log.median(),color='red',linestyle="dashed",linewidth=1.5)

# Create boxplot to see if there is any outliers in any column or not
# Use subplot() function of matplotlib to create boxplot in this figure itself

    plt.subplot(1, 2, 2)
    plt.title("Box plot")
    sns.boxplot(y=feature_to_log, color="blue")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram is a way to visualize data distribution with the help of one or more variables. Here we are using histplot() function to visualize different data distributions in stock prices.
#
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum. In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. From the above histplot, we can see that now our graph is nearly close to normal distribution & the mean is nearly equal to median.
# From the box plot, We see that outliers are removed by log transformation.
# 2. From the above boxplot we can see that after applying np.log10()
#  method on the independent features "Open" , "High" , "Low" we get a normal distribution curve which helps to remove the outliers from the column "Open" , "High" , "Low". We can also find the quartile (q1 , q2 , q3)
#
# 3. From the above graphs, we got the following approximate results:-
#    1. For Feature "Open" :- Lower Quartile (Q1) :- 3.6, Median (Q2) :- 4.3, Upper Quartile (Q3) :- 5.0
#
#    2. For Feature "High" :- Lower Quartile (Q1) :- 3.6, Median (Q2) :- 4.4, Upper Quartile (Q3) :- 5.1
#    3. For Feature "Low" :- Lower Quartile (Q1) :- 3.3, Median (Q2) :- 4.1, Upper Quartile (Q3) :- 4.9

# %% [markdown]
# #### Chart - 7 Bivariate Analysis of closing stock price

# %%
# Chart - 7 visualization code
# Bivariate analysis.
# find correlation betweeen different dependent variables "Close" to all independent variable

for col in numerical_columns:
  fig=plt.figure(figsize=(8,5))
  ax=fig.gca()
  feature=df[col]  # store column in variable
  label=df['Close'] # it store independent variable
  correlation= round(feature.corr(label),5)  # finding correlation and round it upto 5 decimal places
  sns.regplot(x=df[col],y=df["Close"],line_kws={"color": "Red"})   # plot data
  plt.xlabel(col)
  plt.ylabel('Close')
  ax.set_title('Close vs ' +col +'- correlation: '+ str(correlation))  # print correlation value with title

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This Chart is used to plot data and a linear regression model fit. There are a number of mutually exclusive options for estimating the regression model. Regplot() performs a simple linear regression model fit and plot. It is also an axes-level function. That is why we choose this chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. The above graphs depicts that there is high correlation between dependent (Close) and independent (High, Low, Open) features.
# 2. We will try to reduce the correlation for better prediction of the model.

# %% [markdown]
# #### Chart - 8 Multicollinearity

# %%
# Chart - 8 visualization code
# Multicollinearity
# Calculate VIF(Variation Inflation Factor) to see the correlation between independent variables
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calc_vif(X):

    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

    return(vif)

calc_vif(df[[i for i in df.describe().columns if i not in ['Date','Close']]])
# Out:
#   variables         VIF
# 0      Open  175.185704
# 1      High  167.057523
# 2       Low   71.574137

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Variance Inflation Factor (VIF):
#
# Variance inflation factor (VIF) is a measure of the amount of multicollinearity in a set of multiple regression variables. Mathematically, the VIF for a regression model variable is equal to the ratio of the overall model variance to the variance of a model that includes only that single independent variable. This ratio is calculated for each independent variable.
#
# A high VIF indicates that the associated independent variable is highly collinear with the other variables in the model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. VIF scores are high so it implies that associated independent variables are highly collinear to each other in the dataset.
# 2. As all the variables are equally important for closing stock price prediction, So we will not be performing any kind of feature engineering here.
# 3. We are not removing any column because all the columns are equally important for prediction.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From this above table we can see that removing any column lead to loss of valuable information(features) which are essential for accurate prediction for the model. It eventually results in bad model. So, we are not deleting any featues form the dataset and try to predict the result as it is and see how the model performs with multicollinearity and evaluate the performance of the model.

# %% [markdown]
# #### Chart - 9 Candlestick chart of stock prices

# %%
# Chart - 9 visualization code
fig = go.Figure(data=[go.Candlestick(x=df['Date'],
                  open=df['Open'],
                  high=df['High'],
                  low=df['Low'],
                  close=df['Close']
                                     )])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2afbf74a-4a3e-4b37-94ef-f669a4501fd9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2afbf74a-4a3e-4b37-94ef-f669a4501fd9")) {                    Plotly.newPlot(                        "2afbf74a-4a3e-4b37-94ef-f669a4501fd9",                        [{"close":[12.46,13.42,13.3,12.99,13.41,13.71,15.33,16.12,20.08,19.49,18.03,15.62,16.16,17.84,18.46,22.78,25.32,26.97,30.16,28.63,28.14,30.31,33.51,35.98,37.93,36.99,41.36,43.48,46.18,49.81,50.54,49.42,33.75,34.06,31.13,22.85,25.45,26.83,24.13,13.58,12.26,15.03,12.24,10.26,9.98,15.45,25.12,29.68,31.93,33.45,40.99,47.31,50.57,53.41,49.84,47.32,50.97,57.1,57.57,53.83,58.99,62.22,70.3,71.86,61.21,62.54,52.59,51.29,61.98,61.02,60.07,62.38,62.13,55.61,54.5,62.9,54.49,47.72,65.99,69.14,73.46,70.07,66.02,67.83,72.85,65.97,76.44,82.29,88.48,92.84,104.41,94.5,85.71,100.28,97.49,92.2,64.76,48.65,57.5,73.76,73.74,74.02,61.59,60.95,82.7,88.14,113.89,108.38,108.21,114.33,111.7,136.83,142.08,154.57,172.5,172.55,163.31,167.96,176.52,168.6,165.74,137.9,145.92,151.82,153.3,145.23,149.38,137.67,172.91,188.73,206.39,221.3,243.44,272.56,250.85,253.52,234.28,231.26,279.1,290.56,309.82,326.14,286.38,292.37,361.96,351.15,350.0,314.35,306.8,315.05,354.45,322.25,304.9,362.05,346.2,339.6,367.9,343.4,183.45,188.05,169.65,181.75,194.3,231.2,275.05,168.0,147.95,108.7,91.3,59.5,41.45,70.45,68.3,46.95,39.2,34.55,22.45,27.95,26.85,25.6,11.95,14.37,13.15,12.42,14.67],"high":[14.0,14.88,14.87,14.47,13.88,14.44,17.16,16.97,20.95,20.8,21.8,18.4,17.2,18.6,18.88,24.2,28.47,29.66,34.16,32.6,31.58,31.99,36.14,36.38,41.04,39.0,41.75,47.3,50.98,54.0,55.56,53.97,48.9,35.8,36.88,32.22,30.5,28.98,29.8,25.0,17.8,16.56,18.34,12.5,11.24,17.51,28.84,31.08,33.16,35.18,41.3,52.34,54.98,55.67,57.58,51.48,52.06,59.48,58.08,59.9,60.94,68.88,71.74,76.0,77.6,68.36,63.54,57.69,65.2,68.26,61.68,63.39,68.0,63.96,60.08,64.8,63.7,59.8,66.5,74.8,77.88,76.1,70.59,70.6,73.19,74.78,77.69,84.2,89.6,95.0,107.0,107.8,100.15,101.8,109.43,102.94,100.4,67.81,78.94,76.44,77.27,83.0,76.35,62.7,83.36,94.98,117.6,117.57,114.46,118.69,126.85,137.8,143.91,155.0,179.0,173.88,182.0,172.8,176.96,179.4,175.58,169.19,155.5,155.94,157.96,154.52,149.9,157.85,175.12,190.44,209.0,223.0,247.18,275.0,290.0,265.5,262.72,245.0,284.31,294.19,311.57,330.58,330.3,306.34,372.0,368.52,383.25,375.75,329.8,319.0,366.0,366.5,325.8,368.75,364.4,350.1,393.35,404.0,350.0,268.45,231.4,194.3,236.3,236.9,281.3,285.9,178.05,153.8,110.6,92.4,72.55,76.65,75.35,70.5,48.5,40.7,87.95,30.45,31.6,31.95,28.3,17.16,15.34,14.01,14.9],"low":[11.25,12.55,12.27,12.4,12.88,13.0,13.58,15.4,16.02,18.02,15.8,13.4,13.82,15.7,16.8,18.5,21.4,24.4,27.0,26.8,23.31,26.2,29.11,30.4,35.02,30.2,35.3,33.6,40.02,45.0,30.24,44.4,24.11,28.51,30.03,22.62,20.4,24.62,21.7,11.01,11.25,11.13,11.48,9.9,8.16,9.94,14.76,23.0,24.83,29.0,32.0,36.8,42.84,48.6,46.42,44.6,47.3,48.8,50.66,52.6,53.02,59.01,62.51,68.21,58.0,55.44,49.39,46.71,50.8,60.5,54.5,54.8,61.36,50.51,51.2,48.1,52.04,47.4,46.11,63.6,66.2,69.11,58.85,62.14,67.57,65.27,64.46,75.6,82.22,88.01,93.2,93.4,83.42,83.43,97.2,87.15,57.71,43.22,44.8,56.08,64.65,71.63,60.8,58.42,60.34,80.8,86.98,101.62,100.44,103.31,107.18,109.2,132.44,134.0,150.47,156.1,156.8,154.53,157.8,158.9,156.45,118.0,127.0,141.73,144.03,133.71,126.45,132.74,138.35,165.33,181.28,201.14,221.35,240.68,231.2,245.8,219.1,218.25,226.3,275.61,283.6,300.2,275.15,280.21,290.78,337.37,345.5,299.0,296.0,300.65,307.35,304.65,285.1,303.3,325.7,327.35,332.45,338.0,166.15,168.6,147.0,160.2,181.15,167.65,228.8,165.3,133.05,98.75,81.75,53.15,40.95,29.05,59.95,40.7,36.55,33.6,5.55,20.3,25.2,25.55,11.1,11.85,12.75,12.11,12.21],"open":[13.0,12.58,13.48,13.2,13.35,13.49,13.68,15.5,16.2,20.56,19.8,18.2,16.0,15 ...

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# In financial technical analysis, a candlestick pattern is a movement in prices shown graphically on a candlestick chart that some believe can predict a particular market movement.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As the name suggests, a single candlestick pattern is formed by just one candle. So we can imagine, the trading signal is generated based on one day's trading action. The trades based on a single candlestick pattern can be extremely profitable provided the pattern has been identified and executed correctly.
#
# We need to pay some attention to the length of the candle while trading based on candlestick patterns. The length signifies the range for the day. In general, the longer the candle, the more intense is the buying or selling activity. If the candles are short, it can be concluded that the trading action was subdued.
#
# https://en.wikipedia.org/wiki/Candlestick_pattern#/media/File:Candlestick_chart_scheme_03-en.svg

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# If we check onto the September, 2018 candlestick pattern, we can see that the candlestick represents a bearish pattern. The market opens with a high stock price but eventually drops significantky. It might be the longest selling streak that can be seen in September, 2018 candlestick pattern. This is due to the fraud case Yes Bank suffered a huge loss.

# %% [markdown]
# #### Chart - 10 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
# Correlation between each and every column of the dataframe

plt.figure(figsize=(12,8))
correlation = df.corr()
sns.heatmap(abs(correlation), annot=True, cmap='YlGnBu')
# Out:
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is a graphical representation of data that uses a system of color-coding to represent different values across the dataset.
#
# A Multivariate plot like the heatmap is helpful to visualise due to its color coding nature.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above heat map shows that all the features are highly correlated with each other.

# %% [markdown]
# #### Chart - 11 - Pair Plot

# %%
# Pair Plot visualization code
# It will plot each and every column of our dataframe in comparison with the other column

colors = iter(['xkcd:red purple', 'xkcd:pale teal', 'xkcd:warm purple',
       'xkcd:light forest green', 'xkcd:blue with a hint of purple',
       'xkcd:light peach', 'xkcd:dusky purple', 'xkcd:pale mauve',
       'xkcd:bright sky blue', 'xkcd:baby poop green', 'xkcd:brownish',
       'xkcd:moss green', 'xkcd:deep blue', 'xkcd:melon',
       'xkcd:faded green', 'xkcd:cyan', 'xkcd:brown green',
       'xkcd:purple blue', 'xkcd:baby shit green', 'xkcd:greyish blue'])

def my_scatter(x,y, **kwargs):
    kwargs['color'] = next(colors)
    plt.scatter(x,y, **kwargs)

def my_hist(x, **kwargs):
    kwargs['color'] = next(colors)
    plt.hist(x, **kwargs)

g = sns.PairGrid(df)
g.map_diag(my_hist)
g.map_offdiag(my_scatter)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It is a grid of scatterplots and histograms that allows us to quickly examine pairwise relationships between numerical variables.
#
# Creating a pairplot in Seaborn allows us to visualize the relationship between every numeric variable in the dataset at once. The relationship of a variable with itself is displayed as a histogram, and its correlation to other variables is displayed as a scatterplot. This is helpful to understand the types of variables contained and their distribution within the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The above pair plot shows high correlation among variables.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# Hypothesis testing is a tool for making statistical inferences about the population data. It is an analysis tool that tests assumptions and determines how likely something is within a given standard of accuracy. Hypothesis testing provides a way to verify whether the results of an experiment are valid.
#
# Hypothesis testing can be defined as a statistical tool that is used to identify if the results of an experiment are meaningful or not. It involves setting up a null hypothesis and an alternative hypothesis. These two hypotheses will always be mutually exclusive. This means that if the null hypothesis is true then the alternative hypothesis is false and vice versa.
#
# The null hypothesis is a concise mathematical statement that is used to indicate that there is no difference between two possibilities. In other words, there is no difference between certain characteristics of data. This hypothesis assumes that the outcomes of an experiment are based on chance alone. It is denoted as H0. Hypothesis testing is used to conclude if the null hypothesis can be rejected or not.
#
# The alternative hypothesis is an alternative to the null hypothesis. It is used to show that the observations of an experiment are due to some real effect. It indicates that there is a statistical significance between two possible outcomes and can be denoted as H1 or Ha.

# %% [markdown]
# **Statement1:** There is a significant difference in the mean closing prices between the first half (2005-2017) and the second half (2018-2020) of the dataset.
#
# **Statement2:** There is a significant difference in the mean closing prices between months with high opening prices and months with low opening prices.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Null Hypothesis (H0)**: There is no significant difference in the mean closing prices between the first half and the second half of the dataset.
#
# **Alternate Hypothesis (H1)**: There is a significant difference in the mean closing prices between the first half and the second half of the dataset

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
#setting the Date as index.
df1= df.copy()
df1.set_index('Date', inplace=True)

# %%
df1
# Out:
#              Open   High    Low  Close
# Date
# 2005-07-01  13.00  14.00  11.25  12.46
# 2005-08-01  12.58  14.88  12.55  13.42
# 2005-09-01  13.48  14.87  12.27  13.30
# 2005-10-01  13.20  14.47  12.40  12.99
# 2005-11-01  13.35  13.88  12.88  13.41
# ...           ...    ...    ...    ...
# 2020-07-01  25.60  28.30  11.10  11.95
# 2020-08-01  12.00  17.16  11.85  14.37
# 2020-09-01  14.30  15.34  12.75  13.15
# 2020-10-01  13.30  14.01  12.11  12.42
# 2020-11-01  12.41  14.90  12.21  14.67
#
# [185 rows x 4 columns]

# %%
# Perform Statistical Test to obtain P-Value
import numpy as np
from scipy import stats

# Divide the dataset into two halves: first half and second half
first_half = df1['Close'][df1.index.year <= 2017]
second_half = df1['Close'][df1.index.year >= 2018]

# Calculate the means and standard deviations of the two halves
mean1 = np.mean(first_half)
mean2 = np.mean(second_half)
std1 = np.std(first_half)
std2 = np.std(second_half)

# Calculate the sample sizes
n1 = len(first_half)
n2 = len(second_half)

# Calculate the standard error of the difference between means
standard_error = np.sqrt((std1**2 / n1) + (std2**2 / n2))

# Calculate the z-score
z = (mean1 - mean2) / standard_error

# Calculate the p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z)))

# Set the significance level
alpha = 0.05

# Compare the p-value with the significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in means.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in means.")
# Out:
# Reject the null hypothesis. There is a significant difference in means.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Z test, as our data has more than 30 records.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Our dataset has more than 30 records, and we can calculate mean and sd from it. That is why we have choosen the Z test.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# **Statement:** There is a significant difference in the mean closing prices between months with high opening prices and months with low opening prices.
#
# **Null Hypothesis (H0):** The mean closing prices in months with high opening prices are equal to or lower than the mean closing prices in months with low opening prices.
#
# **Alternative Hypothesis (HA):** The mean closing prices in months with high opening prices are higher than the mean closing prices in months with low opening prices.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value

from scipy import stats

# Calculate the mean opening and closing prices for each month
df1['Month'] = df1.index.strftime('%Y-%m')
monthly_data = df1.groupby('Month').agg({'Open': 'mean', 'Close': 'mean'})

# Define the threshold for high and low opening prices
threshold = monthly_data['Open'].median()

# Divide the data into groups based on opening prices
high_opening_prices = monthly_data[monthly_data['Open'] > threshold]['Close']
low_opening_prices = monthly_data[monthly_data['Open'] <= threshold]['Close']

# Calculate the sample statistics
mean_high = np.mean(high_opening_prices)
mean_low = np.mean(low_opening_prices)
std_high = np.std(high_opening_prices)
std_low = np.std(low_opening_prices)
n_high = len(high_opening_prices)
n_low = len(low_opening_prices)

# Calculate the z-statistic
z_statistic = (mean_high - mean_low) / np.sqrt((std_high**2 / n_high) + (std_low**2 / n_low))

# Calculate the p-value
p_value = 1 - stats.norm.cdf(z_statistic)

# Set the significance level
alpha = 0.05

# Compare the p-value with the significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in the mean closing prices.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in the mean closing prices.")
# Out:
# Reject the null hypothesis. There is a significant difference in the mean closing prices.

# %%
from scipy import stats

# Divide the data into groups based on opening prices
high_opening_prices = df1[df1['Open'] > threshold]['Close']
low_opening_prices = df1[df1['Open'] <= threshold]['Close']

# Perform independent t-test
t_statistic, p_value = stats.ttest_ind(high_opening_prices, low_opening_prices)

# Set the significance level
alpha = 0.05

# Compare the p-value with the significance level
if p_value < alpha:
    print("Reject the null hypothesis. There is a significant difference in the mean closing prices.")
else:
    print("Fail to reject the null hypothesis. There is no significant difference in the mean closing prices.")
# Out:
# Reject the null hypothesis. There is a significant difference in the mean closing prices.

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# We have done t test and z test.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# Our dataset is not normally distrubuted. There is skewenss involved. Our dataset is right skewed, that's why we have choosen this specific statistical test.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df1.isnull().sum()
# Out:
# Open     0
# High     0
# Low      0
# Close    0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# Can impute numerical features with mean or median. But, surprisingly, No missing values are found in the dataset. So, there is no need of handling missing values.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
sns.boxplot(df1)
# Out:
# <Axes: >

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Only a few outliers exist in every column. But these outliers need not to be handled as they are less than high fence

# %% [markdown]
# ### 3. Categorical Encoding

# %% [markdown]
# No categoriacl features found in the given dataset.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# No categorical features & texual data found in the given dataset

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
# As all the independent variables are highly correlated, we can create a new feature by takinig mean from the each record of
# independent variables. This will avoid MultiCollinearity and also overfitting of the model.


df1['Mean_OHL'] = df1[['Open', 'High', 'Low']].mean(axis=1)
df1
# Out:
#              Open   High    Low  Close   Mean_OHL
# Date
# 2005-07-01  13.00  14.00  11.25  12.46  12.750000
# 2005-08-01  12.58  14.88  12.55  13.42  13.336667
# 2005-09-01  13.48  14.87  12.27  13.30  13.540000
# 2005-10-01  13.20  14.47  12.40  12.99  13.356667
# 2005-11-01  13.35  13.88  12.88  13.41  13.370000
# ...           ...    ...    ...    ...        ...
# 2020-07-01  25.60  28.30  11.10  11.95  21.666667
# 2020-08-01  12.00  17.16  11.85  14.37  13.670000
# 2020-09-01  14.30  15.34  12.75  13.15  14.130000
# 2020-10-01  13.30  14.01  12.11  12.42  13.140000
# 2020-11-01  12.41  14.90  12.21  14.67  13.173333
#
# [185 rows x 5 columns]

# %%
#checking for linear relationship b/w dependent variable and Independent variable
sns.lmplot(x='Mean_OHL', y='Close', fit_reg=True, data=df1)

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
y_dependent = df1.dropna().Close.values
x_independent = df1.dropna().drop(['Close','Open','High','Low'], axis=1)

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# I choose Open, High, Close & Low. I think they must be included because when opening price is high and low, there is a significant change in closing price.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?
#
# Yes,independent variables and dependent variables have skeweness. I have used log transformation as the skewness is small.

# %%
# Transform Your data

x_independent['Mean_OHL'] = np.log10(x_independent['Mean_OHL'])

# Create the dependent variable data
Y = np.log10(y_dependent)

x_independent.values
# Out:
# array([[1.10551018],
#        [1.1250473 ],
#        [1.13161866],
#        [1.12569809],
#        [1.12613141],
#        [1.13492049],
#        [1.1704573 ],
#        [1.20294217],
#        [1.24854541],
#        [1.29651894],
#        [1.28179064],
#        [1.22184875],
#        [1.19516137],
#        [1.22358246],
#        [1.25269125],
#        [1.3116126 ],
#        [1.38423391],
#        [1.42302731],
#        [1.47011635],
#        [1.47518675],
#        [1.44813925],
#        [1.45326736],
#        [1.50474264],
#        [1.52577881],
#        [1.57225185],
#        [1.55104316],
#        [1.58149454],
#        [1.61172331],
#        [1.65449741],
#        [1.68544315],
#        [1.65574653],
#        [1.69679309],
#        [1.60891808],
#        [1.51503446],
#        [1.52810217],
#        [1.45768009],
#        [1.39064077],
#        [1.41830129],
#        [1.41597441],
#        [1.30542303],
#        [1.16474929],
#        [1.1259148 ],
#        [1.17705529],
#        [1.06182931],
#        [0.99122608],
#        [1.09679419],
#        [1.29768758],
#        [1.42422807],
#        [1.46582882],
#        [1.5058732 ],
#        [1.55266822],
#        [1.63795646],
#        [1.68244594],
#        [1.71391035],
#        [1.72043496],
#        [1.68448629],
#        [1.69066852],
#        [1.72413928],
#        [1.74214883],
#        [1.7512791 ],
#        [1.74691948],
#        [1.79539333],
#        [1.81745518],
#        [1.85553935],
#        [1.84052429],
#        [1.79145672],
#        [1.76816927],
#        [1.71988347],
#        [1.74777422],
#        [1.80336606],
#        [1.77193027],
#        [1.77473588],
#        [1.80699351],
#        [1.77175891],
#        [1.74632277],
#        [1.74481435],
#        [1.77315233],
#        [1.7382519 ],
#        [1.72843495],
#        [1.83314711],
#        [1.85142143],
#        [1.86298561],
#        [1.82356117],
#        [1.81996048],
#        [1.84283797],
#        [1.85136028],
#        [1.84167225],
#        [1.89615864],
#        [1.92832756],
#        [1.95778282],
#        [1.99033885],
#        [2.00804631],
#        [1.96625127],
#        [1.95573584],
#        [2.01089331],
#        [1.98391181],
#        [1.92170381],
#        [1.77092561],
#        [1.7607742 ],
#        [1.80281932],
#        [1.85717162],
#        [1.88277112],
#        [1.84898921],
#        [1.7845222 ],
#        [1.83297702],
#        [1.93656401],
#        [1.99030925],
#        [2.04661221],
#        [2.03252475],
#        [2.04060234],
#        [2.0652435 ],
#        [2.07809415],
#        [2.13930174],
#        [2.15743662],
#        [2.20760744],
#        [2.22399753],
#        [2.23350376],
#        [2.21319003],
#        [2.22596368],
#        [2.23493889],
#        [2.22274248],
#        [2.17906322],
#        [2.1441693 ],
#        [2.17087751],
#        [2.17966667],
#        [2.16754378],
#        [2.14752174],
#        [2.16730749],
#        [2.17827653],
#        [2.2453399 ],
#        [2.28636664],
#        [2.32259139],
#        [2.36203614],
#        [2.40350944],
#        [2.42297265],
#        [2.40637551],
#        [2.39024015],
#        [2.36713841],
#        [2.39362784],
#        [2.45239985],
#        [2.47019971],
#        [2.49618213],
#        [2.49203829],
#        [2.46399745],
#        [2.50325486],
#        [2.55181176],
#        [2.55620196],
#        [2.53544181],
#        [2.4966068 ],
#        [2.4898882 ],
#        [2.51734988],
#        [2.53408959],
#        [2.49210823],
#        [2.51279553],
#        [2.54528649],
#        [2.53379323],
#        [2.55055446],
#        [2.568964  ],
#        [2.45906564],
#        [2.3131991 ],
#        [2.27905826],
#        [2.24592374],
#        [2.30124709],
#        [2.30215048],
#        [2.3948601 ],
#        [2.38512942],
#        [2.19902343],
#        [2.12548127],
#        [2.00281378],
#        [1.89348435],
#        [1.76092485],
#        [1.69225924],
#        [1.83737797],
#        [1.78103694],
#        [1.64328814],
#        [1.5774918 ],
#        [1.63245729],
#        [1.38649897],
#        [1.45024911],
#        [1.45357313],
#        [1.3357921 ],
#        [1.13576851],
#        [1.15014216],
#        [1.11859537],
#        [1.11969568]])

# %%
# Log tranformation to convert the data distribution to normal distribution

for col in numerical_columns:
    plt.figure(figsize=(20, 6))
    plt.subplot(1, 2, 1)
    plt.title("Distribution Curve")

# np.log() is a method in numpy library to convert our dataset values into log transformation to get a normal distribution curve

    feature_to_log = np.log(df[col])  # assign log tranformation value into a variable
    sns.histplot(feature_to_log, color="red", kde=True)

# The Axes. axvline() function in axes module of matplotlib library is used to add a vertical line across the axis.
# It will show where the "mean" and "median" lie for each plot

    plt.ylabel("Count", size=14)
    plt.axvline(feature_to_log.mean(),color='magenta',linewidth=1.5)
    plt.axvline(feature_to_log.median(),color='red',linestyle="dashed",linewidth=1.5)

# Create boxplot to see if there is any outliers in any column or not
# Use subplot() function of matplotlib to create boxplot in this figure itself

    plt.subplot(1, 2, 2)
    plt.title("Box plot")
    sns.boxplot(y=feature_to_log, color="blue")

plt.show()

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# As we have only few features, dimensionality reduction is not necessary
#
# Price Range: Instead of using Open, High, and Low separately, we can calculate the price range as the difference between the High and Low prices. This variable represents the volatility or fluctuation in the stock price for each period and can provide additional information to the model.
#
# Average Price: Another approach is to calculate the average price as the average of the Open, High, and Low prices. This variable represents the overall price level for each period and can be useful in capturing the general trend or level of the stock price.

# %% [markdown]
# ### 8. Data Splitting

# %%
#seperating independent and dependent variables
independent_variables=[ 'Open', 'High', 'Low']
print("Independent_variables:",independent_variables)

dependent_variable=['Close']
print("Dependent_variable:",dependent_variable)
# Out:
# Independent_variables: ['Open', 'High', 'Low']
# Dependent_variable: ['Close']

# %%
#veiwing x and y.
x=df1[independent_variables]
y=df1[dependent_variable]
print(x)
print(y)
# Out:
#              Open   High    Low
# Date
# 2005-07-01  13.00  14.00  11.25
# 2005-08-01  12.58  14.88  12.55
# 2005-09-01  13.48  14.87  12.27
# 2005-10-01  13.20  14.47  12.40
# 2005-11-01  13.35  13.88  12.88
# ...           ...    ...    ...
# 2020-07-01  25.60  28.30  11.10
# 2020-08-01  12.00  17.16  11.85
# 2020-09-01  14.30  15.34  12.75
# 2020-10-01  13.30  14.01  12.11
# 2020-11-01  12.41  14.90  12.21
#
# [185 rows x 3 columns]
#             Close
# Date
# 2005-07-01  12.46
# 2005-08-01  13.42
# 2005-09-01  13.30
# 2005-10-01  12.99
# 2005-11-01  13.41
# ...           ...
# 2020-07-01  11.95
# 2020-08-01  14.37
# 2020-09-01  13.15
# 2020-10-01  12.42
# 2020-11-01  14.67
#
# [185 rows x 1 columns]

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 3)
print(x_train.shape)
print(x_test.shape)
# Out:
# (138, 3)
# (47, 3)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# I have used 80 percent of the data for training the model and 20 % for testing the model.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# The dataset is slightly imbalenced. But Stock price prediction is often inherently imbalanced because stock prices tend to exhibit long periods of stability punctuated by short periods of volatility. In such cases, imbalanced data is expected, and balancing it may not be necessary.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1
#
# We are implementing Basic Linear regression model.
#
# The linear regression model assumes that the relationship between the dependent variable (Close) and the independent variables is linear, which means that the change in the dependent variable is proportional to the change in the independent variables.
#
# During the training process, the linear regression model tries to find the values of the coefficients that minimize the sum of the squared differences between the predicted values and the actual values of the dependent variable.

# %%
# ML Model - 1 Implementation
lr=LinearRegression()

# Fit the Algorithm
reg_with_transformation = lr.fit(x_train, y_train)

# %%
reg_with_transformation.score(x_train,y_train)
# Out:
# 0.9948662565918831

# %%
# Predict on the model
y_pred=lr.predict(x_test)
print('y_pred=',y_pred)
# Out:
# y_pred= [[ 33.23891773]
#  [ 14.36494673]
#  [ 54.3239362 ]
#  [ 49.39841424]
#  [ 27.63337255]
#  [142.21358486]
#  [ 16.70883467]
#  [376.97944101]
#  [ 62.51597095]
#  [ 64.42563433]
#  [ 65.36779675]
#  [325.4447297 ]
#  [ 25.15002426]
#  [163.46363343]
#  [ 14.46907952]
#  [ 22.84811117]
#  [ 29.05249436]
#  [ 58.41250462]
#  [167.35997974]
#  [ 91.11419985]
#  [ 22.83556218]
#  [374.39659058]
#  [ 90.87482753]
#  [ 29.60837245]
#  [ 44.46536869]
#  [ 33.8162293 ]
#  [135.51647704]
#  [ 14.1714373 ]
#  [ 57.93163958]
#  [ 62.25474686]
#  [324.18605191]
#  [ 33.50719057]
#  [262.94662779]
#  [143.46848727]
#  [ 62.91864046]
#  [ 83.46865063]
#  [ 44.97961337]
#  [ 54.2925036 ]
#  [ 59.52929879]
#  [294.72195983]
#  [175.72057598]
#  [244.0473504 ]
#  [181.47649153]
#  [ 51.884986  ]
#  [ 28.39849024]
#  [ 14.44622668]
#  [ 14.55637021]]

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
mae=mean_absolute_error(y_test,y_pred)
print('Mean absolute error=',mae)

#finding r2_score
r2=r2_score(y_test,y_pred)
print('R2 score=',r2)

#calculating adjusted
adjusted_r2=1 - (1 - r2) * ((len(y) -1)/(len(y) - len(independent_variables) - 1))
print('Adjusted_R2 score=',adjusted_r2)
# Out:
# Mean absolute error= 4.325799407757501
# R2 score= 0.9953878715998845
# Adjusted_R2 score= 0.9953114274827555

# %%
# Plotting the actual and predicted test data.
plt.figure(figsize=(9,5))
plt.plot(y_pred)
plt.plot(np.array(y_test))
plt.legend(["Predicted","Actual"])
plt.xlabel('Test Data')
plt.ylabel("Price")
plt.title("Actual vs Predicted Closing price Linear regression")
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import GridSearchCV
parameter = {
    'fit_intercept': [True, False],
    'copy_X': [True, False],

    'positive': [True, False]
}

# Create the grid search object
Lr_gs=GridSearchCV(reg_with_transformation,param_grid=parameter,cv=5,scoring='r2')

# Fit the Algorithm
Lr_gs.fit(x_train,y_train)

# Predict on the model
y_pred_test_gs=Lr_gs.predict(x_test)
y_pred_train_gs=Lr_gs.predict(x_train)

# %%
# Visualizing evaluation Metric Score chart
mae=mean_absolute_error(y_test,y_pred_test_gs)
print('Mean absolute error=',mae)

#finding r2_score
r2=r2_score(y_test,y_pred_test_gs)
print('R2 score=',r2)

#calculating adjusted
adjusted_r2=1 - (1 - r2) * ((len(y) -1)/(len(y) - len(independent_variables) - 1))
print('Adjusted_R2 score=',adjusted_r2)
# Out:
# Mean absolute error= 4.339641263460482
# R2 score= 0.9952019876187094
# Adjusted_R2 score= 0.9951224625516162

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Overall, the model shows good performance on both the train and test sets, with low errors and high R2 scores. However, it is important to monitor the adjusted R2 score and consider potential overfitting when interpreting the results. To overcome that, we can apply regularization techniques.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Model has improved in terms of predicting the unseen data.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# Here, I am going to implement Elastic-Net Regression.
#
# Elastic-Net Regression is a modification of Linear Regression which shares the same hypothetical function for prediction

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
from sklearn.linear_model import ElasticNet,ElasticNetCV
from sklearn.model_selection import TimeSeriesSplit
# 5 fold time-series cross-validation
tscv = TimeSeriesSplit(n_splits=5)
# ML Model - 2 Implementation
eln=ElasticNetCV(cv=tscv)
# Fit the Algorithm
eln.fit(x_train,y_train)
# Predict on the model
y_pred=eln.predict(x_test)
print('y_pred=',y_pred)
# Out:
# y_pred= [ 33.96836555  14.54243005  55.57149506  46.52584284  27.46168089
#  142.21730992  16.55635483 374.24114917  63.81157332  65.30421183
#   66.6950556  329.02038567  25.46968388 159.48421548  14.71028373
#   21.62956225  29.09094156  56.59516911 168.09999285  91.63011435
#   22.4669137  369.21548027  90.04895518  29.56402247  47.20756277
#   34.09955551 136.92953101  14.36635268  58.78441392  62.71222533
#  323.09979823  33.84532102 262.72110258 142.19006847  59.94589457
#   82.93667246  44.28500386  55.00999932  59.96728717 294.09151314
#  175.1695558  241.57239007 190.38949478  52.67601072  28.24281901
#   14.6574762   14.41615962]

# %%
#finding mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print('Mean absolute error=',mae)

#finding r2_score
r2=r2_score(y_test,y_pred)
print('r2 score=',r2)

#calculating adjusted r2 score
adjusted_r2=1 - (1 - r2) * ((len(y) -1)/(len(y) - len(independent_variables) - 1))
print('adjusted_r2 score=',adjusted_r2)
# Out:
# Mean absolute error= 4.544666958556021
# r2 score= 0.9945606276492454
# adjusted_r2 score= 0.9944704723064152

# %%
# Visualizing evaluation Metric Score chart
# Plotting the actual and predicted test data.
plt.figure(figsize=(9,5))
plt.plot(y_pred)
plt.plot(np.array(y_test))
plt.legend(["Predicted","Actual"])
plt.xlabel('Test Data')
plt.ylabel("Price")
plt.title("Actual vs Predicted Closing price Linear regression")
plt.show()

# %% [markdown]
# ### ML Model - 3

# %% [markdown]
# Now, I am going to implement RandomForest model.
#
# Random forest is an ensemble learning algorithm that constructs a multitude of decision trees at training time and outputs the mean prediction of the individual trees as the final prediction.
#
# The RandomForestRegressor class allows you to train a regression model using the random forest algorithm, and then use it to make predictions on new data.
#
# During the training process, the algorithm randomly selects a subset of features and a subset of observations to construct each decision tree.
#
# This helps to reduce overfitting and improve the generalization performance of the model.

# %%
from sklearn.ensemble import RandomForestRegressor
# ML Model - 3 Implementation
rf=RandomForestRegressor()
# Fit the Algorithm
rf.fit(x_train,y_train)
# Predict on the model
y_pred=rf.predict(x_test)
print(y_pred)
# Out:
# [ 36.363   13.3219  55.4818  43.0626  27.3399 138.4764  15.488  339.6717
#   66.3966  69.796   70.3013 344.3441  26.4453 155.1973  12.9073  21.613
#   29.1126  52.5104 172.3843  95.1102  19.41   340.8532  90.0059  29.8038
#   46.328   36.0869 138.226   13.5863  58.463   60.0386 312.7849  36.0176
#  264.0511 140.9103  52.4482  79.4262  45.4331  53.9679  59.8829 281.1463
#  175.965  235.7691 207.1416  51.09    27.5773  13.7018  13.8205]

# %%
#finding mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print('Mean absolute error=',mae)

#finding r2_score
r2=r2_score(y_test,y_pred)
print('r2 score=',r2)

#calculating adjusted r2 score
adjusted_r2=1 - (1 - r2) * ((len(y) -1)/(len(y) - len(independent_variables) - 1))
print('adjusted_r2 score=',adjusted_r2)
# Out:
# Mean absolute error= 6.6292765957447
# r2 score= 0.988772994988412
# adjusted_r2 score= 0.9885869120324188

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Plotting the actual and predicted test data.
plt.figure(figsize=(9,5))
plt.plot(y_pred)
plt.plot(np.array(y_test))
plt.legend(["Predicted","Actual"])
plt.xlabel('Test Data')
plt.ylabel("Price")
plt.title("Actual vs Predicted Closing price Linear regression")
plt.show()

# %% [markdown]
# ### ML Model - 4

# %%
# ML Model - 4 Implementation
xgb=XGBRegressor()
# Fit the Algorithm
xgb.fit(x_train,y_train)
# Predict on the model
y_pred=xgb.predict(x_test)
print('y_pred=',y_pred)
# Out:
# y_pred= [ 32.342472  13.397777  53.127552  43.637245  23.254784 137.69273
#   15.266699 318.46832   60.488792  67.88505   69.18262  348.96362
#   22.631023 159.33424   11.57098   18.729208  30.032745  52.37544
#  172.2621    87.12547   19.178205 318.46832   73.09358   30.032745
#   42.6932    42.295666 137.85329   13.13042   56.97948   63.90926
#  313.22797   33.98598  271.5915   138.35875   58.8752    74.00751
#   44.37197   53.47703   56.159344 285.5533   176.27203  245.80249
#  197.51932   49.520367  26.874529  13.13042   13.928413]

# %%
#finding mean_absolute_error
mae=mean_absolute_error(y_test,y_pred)
print('Mean absolute error=',mae)

#finding r2_score
r2=r2_score(y_test,y_pred)
print('r2 score=',r2)

#calculating adjusted r2 score
adjusted_r2=1 - (1 - r2) * ((len(y) -1)/(len(y) - len(independent_variables) - 1))
print('adjusted_r2 score=',adjusted_r2)
# Out:
# Mean absolute error= 8.181922877697234
# r2 score= 0.983389922360238
# adjusted_r2 score= 0.9831146172059878

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Plotting the actual and predicted test data.
plt.figure(figsize=(9,5))
plt.plot(y_pred)
plt.plot(np.array(y_test))
plt.legend(["Predicted","Actual"])
plt.xlabel('Test Data')
plt.ylabel("Price")
plt.title("Actual vs Predicted Closing price Linear regression")
plt.show()

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# I considered R2. adjusted R2 and MAE as evaluation metrics.
#
# R2 score is a measure of how well the model fits the data.
#
# It ranges from 0 to 1, with a higher value indicating a better fit which means that the model is able to explain a large portion of the variance in the data which could have a positive impact on decision-making.
#
# The adjusted R-squared provides a penalized measure of model fit that takes into account both the explanatory power of the model and the complexity of the model. It is particularly useful when comparing models with different numbers of predictors. A higher adjusted R-squared indicates a better fit of the model, as it reflects the proportion of variance in the dependent variable that is explained by the independent variables, adjusted for the model complexity.
#
# MAE is a measure of the mean absolute error of the model's predictions.
#
# In a business context, a low MAE can indicate that the model is making relatively small errors.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# I am considering XGBRegressor(xgb_gs) as my final model.
#
# This model has the highest R2 and adjusted r2 values on both the training and test sets, which indicates that it is doing a good job of explaining the variance in the target variable and also considering all the features. Elastinet also performed well. but has low adjusted r2 in test data than in the train data. It indicates, that all the feautures are not necessary for Elastinet to predict the closing price.
#
# XGboost capturing all features and still predicting better than Elastinet.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The main goal of the project is to create a machine learning model which can predict the closing price of Yes Bank stock for that month, keeping in mind of the fraud case happened in 2018.
#
# Using data visualization on our target variable, we can clearly see the impact of 2018 fraud case involving Rana Kapoor as the stock prices decline dramatically during that period.
#
# We found that the distribution of all our variables is positively skewed, so we performed log transformation on them.
#
# In conclusion, we can write down few points on our model-
#
# 1. Linear Regression has the lowest Mean Absolute Error (4.33), indicating it has the smallest average absolute difference between predicted and actual values,has the highest R-squared (R2) Score (0.994) which indicates over fitting.
# 2. Linear Regression also has the R-squared (R2) Score (0.991), suggesting that it explains a significant portion of the variance in the data.
# 3. ElasticNetCV and Random Forest Regressor perform well with relatively low Mean Absolute Errors (4.54 and 6.62, respectively) and high R2 scores (0.99 and 0.98, respectively).
# 4. XGBoost Regressor show slightly higher Mean Absolute Errors and lower R2 scores compared to the other models, but they still provide reasonable performance.
# 5. The choice of the best model depends on the specific problem, data, and the trade-off between model complexity and performance.
# 6. In this case, XGBRegressor appears to have the best balance of low error (Mean Absolute Error:8.18, r2 score= 0.9833, adjusted_r2 score= 0.9831 and high R2 score, making it a strong candidate for modeling the data.
#
# Given the dataset and features, Our model is performing well on all data-points. With our model making predictions with such high accuracy, we can confidently deploy this model for further predictive tasks using future data.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
